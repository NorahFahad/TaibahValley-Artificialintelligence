# %% [markdown]
# # **Credit Card Churn🏦**

# %% [markdown]
# >  **Business Problem:** A business manager of a consumer credit card bank is facing the problem of customer attrition. They want to analyze the data to find out the reason behind this and leverage the same to predict customers who are likely to drop off.💳
#
# > **Credit card churning:** is the process of opening cards for the sole purpose of earning welcome bonuses or other benefits. Usually, it involves closing cards after the bonus posts to your account and before the next annual fee is charged. A pattern of opening and closing cards quickly is often a red flag for card issuers.🤑
#
# > **Columns description**: [Credit Card Churn](https://www.kaggle.com/datasets/anwarsan/credit-card-bank-churn)
# * CLIENTNUM: Unique identifier for the customer holding the account
# * Attrition_Flag: Existing Customer	= 1 , Attrited Customer = 0
# * Customer_Age: Customer's Age in Years
# * Gender: M=Male, F=Female
# * Dependent_count: Number of dependents
# * Education_Level: Educational Qualification of the account holder (example: high school, college graduate, etc.)
# * Marital_Status: Married, Single, Divorced, Unknown
# * Income_Category: Annual Income Category of the account holder (< $40K, $40K - 60K, $60K - $80K, $80K-$120K, > $120K, Unknown)
# * Card_Category: Type of Card (Blue, Silver, Gold, Platinum)
# * Months_on_book: Period of relationship with bank
# * Total_Relationship_Count: total number of products held by the customers (cards, accounts, etc.)
# * Months_Inactive_12_mon: No. of months inactive in the last 12 months
# * Contacts_Count_12_mon: No. of Contacts in the last 12 months
# * Credit_Limit: Credit Limit on the Credit Card (A credit limit is the maximum amount you can charge on a revolving credit account, such as a credit card.)
# * Total_Revolving_Bal: Total Revolving Balance on the Credit Card (If you don't pay the balance on your revolving credit account in full every month, the unpaid portion carries over to the next month).
# * Avg_Open_To_Buy: Open to Buy Credit Line (Average of last 12 months)
# * Total_Amt_Chng_Q4_Q1: represents how much the customer increased their expenditure when comparing the 4th quarter against the 1st (Q4 over Q1).
# * Total_Trans_Amt: Total Transaction Amount (Last 12 months)
# * Total_Trans_Ct: Total Transaction Count (Last 12 months)
# * Total_Ct_Chng_Q4_Q1: Change in Transaction Count (Q4 over Q1)
# * Avg_Utilization_Ratio: is the amount of revolving credit you're currently using divided by the total amount of revolving credit you have available. In other words, it's how much you currently owe divided by your credit limit. It is generally expressed as a percent.

# %% [markdown]
# ## **IMPORT LIBRARIES AND LOAD DATA📚**

# %%
#import Libraries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/AI-Tasks/credit_card_churn.csv') #read the csv file

# %% [markdown]
# ## **DATA EXPLORATION🔍**

# %%
pd.set_option("display.max_columns", 50) #to change the default number of columns to be displayed

# %%
data.sample(5)
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 2005  718577958  Attrited Customer            39      M                2
# 7346  767058183  Existing Customer            53      F                1
# 9371  721524858  Existing Customer            51      F                2
# 7316  811081083  Existing Customer            48      F                3
# 6841  711363258  Existing Customer            49      F                1
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 2005      Uneducated        Married         $120K +          Blue
# 7346        Graduate       Divorced  Less than $40K          Blue
# 9371         Unknown        Married  Less than $40K          Blue
# 7316      Uneducated         Single  Less than $40K          Blue
# 6841   Post-Graduate        Married         Unknown          Blue
#
#       Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %%
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
data.shape #(No. rows, No. columns)
# Out:
# (10127, 23)

# %%
data.nunique() #the number of unique value in each column
# Out:
# CLIENTNUM                                                                                                                             10127
# Attrition_Flag                                                                                                                            2
# Customer_Age                                                                                                                             45
# Gender                                                                                                                                    2
# Dependent_count                                                                                                                           6
# Education_Level                                                                                                                           7
# Marital_Status                                                                                                                            4
# ...

# %%
data.describe() #data set describtion
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
data.info() #information about the data set columns, how many non null valueand data type for each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
data.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
data['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
data['Marital_Status'].value_counts()
# Out:
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64

# %%
data['Income_Category'].value_counts()
# Out:
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income_Category, dtype: int64

# %% [markdown]
# ## **DATA CLEANING🧹**

# %% [markdown]
# ### drop unnecessary columns

# %%
data.drop([data.columns[0], data.columns[21],data.columns[22]],axis=1,inplace=True) #delete 3 columns

# %% [markdown]
# ### check for null in each column

# %%
data.isnull().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# * As we can see there is not null values

# %% [markdown]
# ### check for duplicated values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * there is no duplicated

# %% [markdown]
# ### Change data types

# %%
data = data.astype({"Attrition_Flag":'category', "Gender":'category', "Education_Level":'category', "Marital_Status":'category',
                    "Income_Category":'category', "Card_Category":'category'}) #change data types

# %% [markdown]
# ## **DATA VISUALIZATION📈**

# %% [markdown]
# ### ***Categorical Data🕵🏻‍♀️***

# %% [markdown]
# ### Attrition Flag percentage(Target)

# %%
Attrition_Flag = data['Attrition_Flag'].value_counts()
explode = (0, 0.2) #explode to stand out slice
ax = Attrition_Flag.plot(kind='pie', autopct = '%1.1f%%', explode=explode, colors = ['green', 'red'], #autopct: to set the percentage 
                     figsize=(7,5), fontsize=15, shadow=True, wedgeprops={'edgecolor': 'black'})
ax.set_title("Attrition_Flag", fontsize=20)
plt.savefig('Attrition_Flag.png')
plt.show()

# %% [markdown]
# * Existing customer is about 83.9% of the total customer and we have 16.1% attrited customer

# %% [markdown]
# ### Gender

# %%
plt.figure(figsize=(7,6)) #set figure size
ax = sns.countplot(data=data, x="Gender", order = data['Gender'].value_counts().index, palette=['#FFC0CB', '#0000FF'])
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()),(p.get_x()+p.get_width()/2, p.get_height()), ha='center', va='bottom', color = "black", size=12)
plt.title('Gender', fontsize=20)
plt.xlabel('Gender')
plt.savefig('Gender.png')
plt.show()

# %% [markdown]
# * The female customer more than male

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x='Gender', hue='Attrition_Flag', palette='ch:start=.2,rot=-.3')
plt.savefig('Gender0.png')
plt.show()

# %% [markdown]
# * Females existing more than male existing
# * Female attrited more than male attrited

# %% [markdown]
# ### Education Level

# %%
plt.figure(figsize=(8,8)) #set figure size
plt.pie(data.Education_Level.value_counts(), autopct='%1.1f%%', pctdistance=0.85)
centre_circle = plt.Circle((0, 0), 0.50, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.legend(data.Education_Level.value_counts().keys(), loc="upper right", title="Education Level")
plt.title('Education Level.', fontsize=20)
plt.show()

# %% [markdown]
# * the most percentage of graduate customer and the least percentage of doctorate

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x='Education_Level', hue='Attrition_Flag', palette='ch:start=.2,rot=-.3')
plt.savefig('Education_Level.png')
plt.show()

# %% [markdown]
# * Most of the attrited customer are graduated

# %% [markdown]
# ### Marital Status distribution

# %%
plt.figure(figsize=(10,7))
ax = sns.countplot(data=data, x="Marital_Status", palette='binary', order = data['Marital_Status'].value_counts().index)
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()),(p.get_x()+p.get_width()/2, p.get_height()), ha='center', va='bottom', color = "black", size=12)
plt.title('Marital_Status dist.', fontsize=20)
plt.xlabel('Marital Status')
plt.show()

# %% [markdown]
# * Most of the customer are married or single

# %% [markdown]
# ### Annual Income

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x='Income_Category', hue='Attrition_Flag', palette='ch:start=.2,rot=-.3')
plt.savefig('Income_Category.png')
plt.show()

# %% [markdown]
# * Most existing and attrited customer have a annual income of less than $40K

# %% [markdown]
# ### ***Numerical Data🕵🏻‍♀️***

# %% [markdown]
# ### Customer Age distribution

# %%
ax = sns.displot(data['Customer_Age'], kde=True, color='g')
plt.title('Age dist.', fontsize=20) #set figure title
plt.xlabel('Age') #set x label
plt.savefig('Customer_Age.png')
plt.show()

# %%
plt.figure(figsize=(10,5)) #set figure size
g = sns.FacetGrid(data, col="Attrition_Flag", height=4.5, aspect=1.65)
g.map(sns.histplot, "Customer_Age")
g.refline(x=data["Customer_Age"].median())
plt.savefig('Customer_Age0.png')
plt.show()

# %% [markdown]
# * The customer is between 26 and 73 years old
# * Most of the customer are between 42 and 55
# * The mean is about 43 years old

# %% [markdown]
# ### Months Inactive in the last 12 month

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=data['Months_Inactive_12_mon'], order=data['Months_Inactive_12_mon'].value_counts().
             sort_values(ascending = False).index)
plt.title('Months of inactivity in the last year')
plt.savefig('Months_Inactive_12_mon.png')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot(x=data['Months_Inactive_12_mon'], hue='Attrition_Flag', data=data, palette='ch:start=.2,rot=-.3')
plt.savefig('Months_Inactive_12_mon0.png')
plt.show()

# %% [markdown]
# * Customers who are inactive two or three times are the most existing

# %% [markdown]
# ### Total Relationship Count with the bank

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x='Total_Relationship_Count', hue='Attrition_Flag', palette='ch:start=.2,rot=-.3')
plt.savefig('Total_Relationship_Count.png')
plt.show()

# %% [markdown]
# * Most of attrited customer have 3 or 2 relationship with the bank
# * Existing customer have 3 or more relationship with the bank

# %% [markdown]
# ### Dependent count

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x='Dependent_count', hue='Attrition_Flag', palette='ch:start=.2,rot=-.3')
plt.savefig('Dependent_count.png')
plt.show()

# %% [markdown]
# * Existing and attrited customer have 3 or 2 dependent

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x='Contacts_Count_12_mon', hue='Attrition_Flag', palette='ch:start=.2,rot=-.3')
plt.show()

# %% [markdown]
# * Attrited customer contact with the bank or visa vers 1 time or more

# %% [markdown]
# ### Total Trans Amount

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=data, x="Customer_Age", y="Total_Trans_Amt", hue="Attrition_Flag", palette='ch:start=.2,rot=-.3')
plt.show()

# %% [markdown]
# * Existing customer have higher transaction amount than attrited
# * with age the total transactions amount is lower

# %% [markdown]
# ### Total Transaction Amount

# %%
plt.figure(figsize=(10,5)) #set figure size
ax = sns.boxplot(data=data, x='Attrition_Flag', y='Total_Trans_Amt')
plt.title('Total Transaction Amount', fontsize=20)
plt.ylim(top=10000)
plt.xlabel('Total Transaction Amount')
plt.savefig('Total_Trans_Amt.png')
plt.show()

# %% [markdown]
# ### Correlation between numeric features

# %% [markdown]
# * The heatmap shows the pearson correlation coefficient between two variables. <br>
# * (Pearson's correlation coefficient is represented by the Greek letter rho (ρ) for the population parameter and r for a sample statistic. This correlation coefficient is a single number that measures both the strength and direction of the linear relationship between two continuous variables).<br>
# * The correlation shows how strong the relationship between two variables is. It varies between -1 and 1, where 1 is a strong positive relationship and -1 is a strong negative relationship. 0 indicates no relationship.<br>
# * A correlation coefficient of 1 means that a positive increase in one variable is a positive increase of a fixed proportion in the other. A correlation coefficient of -1 means that a positive increase in one variable is a negative decrease of a fixed proportion in the other.

# %%
plt.figure(figsize=(10,10))
corr=data.corr()
sns.heatmap(corr, annot=True, cmap= 'Reds')
plt.show()

# %% [markdown]
# ### Conclusion
# * Attrited customer have less than 40k annual income also they have 2 or 3 dependent
# * Most of attrited customer between 40 and 50 years old also they were inactive 3 or 2 month in the last year

# %% [markdown]
# ## **DATA PREPROCESSING⚙️**

# %% [markdown]
#  ### Encoding Variables + Set features and target columns

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
data = pd.get_dummies(data, columns=['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category']) #covert category columns
le = LabelEncoder()
y = data['Attrition_Flag']
y = le.fit_transform(y)
x = data.iloc[:,data.columns != 'Attrition_Flag'] #take the features which is from column index 1 to the last column

# %%
pd.DataFrame(x)
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# 0                45                3              39
# 1                49                5              44
# 2                51                3              36
# 3                40                4              34
# 4                40                3              21
# ...             ...              ...             ...
# 10122            50                2              40
# 10123            41                2              25
# 10124            44                1              36
# 10125            30                2              36
# 10126            43                2              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                             5                       1
# 1                             6                       1
# 2                             4                       1
# 3                             3                       4
# ...

# %%
pd.DataFrame(y)
# Out:
#        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 10122  1
# 10123  0
# 10124  0
# 10125  0
# 10126  0
#
# [10127 rows x 1 columns]

# %% [markdown]
#  ### Split the dataset for training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0) #random_state=0 to get the same train and test sets across different executions

# %% [markdown]
# ## **MODEL BUILDING🧱**

# %% [markdown]
# ### 1. Model One: Decision Tree Classification Algorithm🌳

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

tree = DecisionTreeClassifier() #create object
tree.fit(x_train, y_train) #train the object

tree_pred = tree.predict(x_test) #predict for the unlabeled data
tree_accuracy = accuracy_score(y_test, tree_pred) #calculate the accuracy between unlabel data and actual data

print("Accuracy Score of Tree Classification Algorithm is: {:0.2f}%".format(tree_accuracy*100))
# Out:
# Accuracy Score of Tree Classification Algorithm is: 94.11%

# %% [markdown]
# ### 2. Model two: Logistic Regression Algorithm

# %%
from sklearn.linear_model import LogisticRegression

regression = LogisticRegression()
regression.fit(x_train, y_train)

regression_pred = regression.predict(x_test)
regression_accuracy = accuracy_score(y_test, regression_pred)

print("Accuracy Score of Logistic Regression Algorithm is: {:0.2f}%".format(regression_accuracy*100))
# Out:
# Accuracy Score of Logistic Regression Algorithm is: 88.19%
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
from sklearn.metrics import plot_confusion_matrix
fig, ax = plt.subplots(figsize=(7,7))
plot_confusion_matrix(regression, x_test, y_test, cmap=plt.cm.Blues, display_labels = ['Existing','Attrited'], ax=ax)
plt.title('Confusion Matrix', fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### 3. Model Three: Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier() #create object
forest.fit(x_train, y_train) #train the object

forest_pred = forest.predict(x_test)
forest_accuracy = accuracy_score(y_test, forest_pred) #calculate the accuracy score

print("Accuracy Score of Random Forest Algorithm is: {:0.4f}%".format(forest_accuracy*100))
# Out:
# Accuracy Score of Random Forest Algorithm is: 95.1300%

# %% [markdown]
# > **Feature Importance** refers to techniques that calculate a score for all the input features for a given model — the scores simply represent the “importance” of each feature. A higher score means that the specific feature will have a larger effect on the model that is being used to predict a certain variable.

# %%
forest = RandomForestClassifier() #create object
forest.fit(x_train, y_train) #train the object
feature_scores = pd.Series(forest.feature_importances_, index=x_train.columns).sort_values(ascending=False)
feature_scores.plot(kind='bar', figsize=(20,5), title='Feature Importance')
plt.show()

# %%
x_train = x_train.loc[:, ['Customer_Age', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Amt_Chng_Q4_Q1', 'Total_Ct_Chng_Q4_Q1', 'Credit_Limit',
                          'Months_Inactive_12_mon', 'Months_on_book', 'Total_Relationship_Count', 'Total_Revolving_Bal']]
x_test = x_test.loc[:, ['Customer_Age', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Amt_Chng_Q4_Q1', 'Total_Ct_Chng_Q4_Q1', 'Credit_Limit',
                          'Months_Inactive_12_mon', 'Months_on_book', 'Total_Relationship_Count', 'Total_Revolving_Bal']]

forest = RandomForestClassifier() #create object
forest.fit(x_train, y_train) #train the object

forest_pred = forest.predict(x_test)
forest_accuracy = accuracy_score(y_test, forest_pred) #calculate the accuracy score

print("Accuracy Score of Random Forest Algorithm After feature_importances is: {:0.4f}%".format(forest_accuracy*100))
# Out:
# Accuracy Score of Random Forest Algorithm After feature_importances is: 96.8740%

# %%
import pickle
pickle.dump(forest, open("fmodel.pkl", "wb")) #save the model

# %% [markdown]
# ## **MODEL DEPLOYMENT🚀**

# %%
pip install gradio #gradio install

# %%
import gradio as gr #import gradio library
def make_prediction(Customer_Age, Total_Relationship_Count, Credit_Limit, Total_Revolving_Bal, Total_Amt_Chng_Q4_Q1, Total_Trans_Amt, 
                    Total_Trans_Ct, Total_Ct_Chng_Q4_Q1, Months_Inactive_12_mon, Months_on_book):
    with open("fmodel.pkl", "rb") as f:
        clf  = pickle.load(f)
        preds = clf.predict([[Customer_Age, Total_Relationship_Count, Credit_Limit, Total_Revolving_Bal, Total_Amt_Chng_Q4_Q1, Total_Trans_Amt, 
                              Total_Trans_Ct, Total_Ct_Chng_Q4_Q1, Months_Inactive_12_mon, Months_on_book]])
    if preds == 1:
            return "The customer may NOT attrited🥳"
    return "The customer MAY attrited🤑"

#Create the input component for Gradio
Customer_Age = gr.Number(label = "Customer Age | عمر العميل")
Total_Relationship_Count = gr.Number(label= "Total Relationship Count with the bank | عدد المنتجات التي تربط العميل بالبنك")
Months_on_book = gr.Number(label= "Total # of Month with the bank | عدد شهور تعامل العميل مع البنك")
Months_Inactive_12_mon = gr.Number(label= "Total # of the last 12 Month the customer was inactve | عدد الشهور العميل خامل ")
Credit_Limit = gr.Number(label = "Credit Limit for the Customer | الحد الائتماني للبطاقة الائتمانية")
Total_Revolving_Bal = gr.Number(label = "Total Revolving Balance | المبلغ المستحق خلال الشهر")
Total_Amt_Chng_Q4_Q1 = gr.Number(label = "Total Amount Change Q4-Q1 | اجمالي التغير في نفقات العميل الربع الاخير - الربع الاول")
Total_Ct_Chng_Q4_Q1 = gr.Number(label = "Total Count Change Q4-Q1 | اجمالي التغير في عدد معاملات العميل الربع الاخير - الربع الاول")
Total_Trans_Amt = gr.Number(label = "Total Transaction Amount | اجمالي قيمة المعاملات ")
Total_Trans_Ct = gr.Number(label = "Total Transaction Count | اجمالي التغير في عدد معاملات للعميل")

result = gr.Textbox(label= "Prediction") #We create the output

app = gr.Interface(fn=make_prediction, inputs=[Customer_Age, Total_Relationship_Count, Months_on_book, Months_Inactive_12_mon, 
                                                 Credit_Limit, Total_Revolving_Bal, Total_Amt_Chng_Q4_Q1,Total_Ct_Chng_Q4_Q1,
                                                 Total_Trans_Amt, Total_Trans_Ct], outputs=result, title="Credit Card Churn Prediction🤑")
app.launch() #launch the app
